# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
data = pd.read_csv("50_Startups.csv")

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data1 = data.rename({'R&D Spend' : 'RDS' , 'Administration' : 'ADMS' , 'Marketing Spend' : 'MS'},axis = 1)
data1
# Out:
#           RDS       ADMS         MS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
data1[data1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [RDS, ADMS, MS, State, Profit]
# Index: []

# %%
data1.describe()
# Out:
#                  RDS           ADMS             MS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
data1.isna().sum()                                       #check for missing values
# Out:
# RDS       0
# ADMS      0
# MS        0
# State     0
# Profit    0
# dtype: int64

# %%
# Check if the specified columns exist in the dataset
specified_columns = ['RDS', 'ADMS', 'MS', 'Profit']
missing_columns = [col for col in specified_columns if col not in data.columns]

if missing_columns:
    print("Columns not found in the dataset:", missing_columns)
else:
    # Add log transformations to specific columns
    data['log_RDS'] = np.log(data['RDS'])
    data['log_ADMS'] = np.log(data['ADMS'])
    data['log_MS'] = np.log(data['MS'])
    data['log_Profit'] = np.log(data['Profit'])
# Out:
# Columns not found in the dataset: ['RDS', 'ADMS', 'MS']

# %%
 # Display the modified dataset with log-transformed columns
print(data)
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# Correlation Matrix

# %%
data1.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4320\3734675979.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data1.corr()
#              RDS      ADMS        MS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# ADMS    0.241955  1.000000 -0.032154  0.200717
# MS      0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data1)

# %% [markdown]
# Preparing a model

# %%
#Build Model

model = smf.ols('Profit~RDS+ADMS+MS',data=data1).fit()

# %% [markdown]
# Model Testing

# %%
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADMS            -0.026816
# MS               0.027228
# dtype: float64

# %%
model.tvalues , np.round(model.pvalues,5)
# Out:
# (Intercept     7.626218
#  RDS          17.846374
#  ADMS         -0.525507
#  MS            1.655077
#  dtype: float64,
#  Intercept    0.00000
#  RDS          0.00000
#  ADMS         0.60176
#  MS           0.10472
#  dtype: float64)

# %%
model.rsquared , model.rsquared_adj                               #Model Accuracy
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %% [markdown]
# Simple Linear Regression Model

# %%
slr_a=smf.ols("Profit~ADMS",data=data1).fit()
slr_a.tvalues , slr_a.pvalues
# Out:
# (Intercept    3.040044
#  ADMS         1.419493
#  dtype: float64,
#  Intercept    0.003824
#  ADMS         0.162217
#  dtype: float64)

# %%
slr_a=smf.ols("Profit~RDS",data=data1).fit()
slr_a.tvalues , slr_a.pvalues
# Out:
# (Intercept    19.320288
#  RDS          29.151139
#  dtype: float64,
#  Intercept    2.782697e-24
#  RDS          3.500322e-32
#  dtype: float64)

# %%
slr_a=smf.ols("Profit~MS",data=data1).fit()
slr_a.tvalues , slr_a.pvalues
# Out:
# (Intercept    7.808356
#  MS           7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  MS           4.381073e-10
#  dtype: float64)

# %%
slr_a=smf.ols("Profit~ADMS+MS",data=data1).fit()
slr_a.tvalues , slr_a.pvalues
# Out:
# (Intercept    1.142741
#  ADMS         2.467779
#  MS           8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  ADMS         1.729198e-02
#  MS           9.727245e-11
#  dtype: float64)

# %% [markdown]
# Calculating VIF

# %%
rsq_r=smf.ols("RDS~ADMS+MS",data=data1).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("ADMS~RDS+MS",data=data1).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("MS~RDS+ADMS",data=data1).fit().rsquared
vif_m=1/(1-rsq_m)

# Putting the values in Dataframe format
d1={'Variables':['RDS','ADMS','MS'],'Vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       RDS  2.468903
# 1      ADMS  1.175091
# 2        MS  2.326773

# %% [markdown]
# Residual Analysis

# %% [markdown]
# Test for Normality of Residuals (Q-Q Plot)

# %%
sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)

def standard_values(vals) : return (vals-vals.mean())/vals.std()  # User defined z = (x - mu)/sigma

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %%
fig=plt.figure(figsize=(10,8))
sm.graphics.plot_regress_exog(model,'ADMS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'RDS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'MS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# Checking Outliers

# %%
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data1)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (49, 0.28808229275432634)

# %%
# Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(model)
plt.show()

# %%
k=data1.shape[1]
n=data1.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
data1[data1.index.isin([49])]
# Out:
#     RDS      ADMS        MS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %% [markdown]
# Improving A model

# %%
data2=data1.drop(data1.index[[49]],axis=0).reset_index(drop=True)
data2
# Out:
#           RDS       ADMS         MS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# Build Model

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RDS+ADMS+MS",data=data2).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data2=data2.drop(data2.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data2
else:
    final_model=smf.ols("Profit~RDS+ADMS+MS",data=data2).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129847

# %%
final_model.rsquared           # Accuracy = 96%
# Out:
# 0.9613162435129847
